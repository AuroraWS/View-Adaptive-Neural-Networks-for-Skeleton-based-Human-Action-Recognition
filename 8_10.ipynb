# %% [markdown]
# <a href="https://colab.research.google.com/github/AuroraWS/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/blob/master/8_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
import os

def get_filenames_without_extension(directory):
    # 检查目录是否存在
    if not os.path.exists(directory):
        print(f"The directory {directory} does not exist.")
        return []
    else:
      print(f'The directory {directory} does exist.')

    filenames = []
    # 遍历目录中的所有文件
    for filename in os.listdir(directory):
        name, _ = os.path.splitext(filename)
        filenames.append(name)
        # print(f'{name} has been processed')

    return filenames

def write_filenames_to_file(filenames, output_file):
    with open(output_file, 'w') as f:
        for name in filenames:
            f.write(name + '\n')

# 使用示例
directory_path = '/content/drive/Othercomputers/我的笔记本电脑/nturgb+d_skeletons'  # 替换为你的目录路径
output_file = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/statistics/skes_available_name.txt'

filenames = get_filenames_without_extension(directory_path)
write_filenames_to_file(filenames, output_file)

print(f"Filenames have been written to {output_file}")
# Out:
# The directory /content/drive/Othercomputers/我的笔记本电脑/nturgb+d_skeletons does exist.
# Filenames have been written to /content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/statistics/skes_available_name.txt

# %%
def read_filenames_from_file(input_file):
    with open(input_file, 'r') as f:
        filenames = f.read().splitlines()
    return filenames

def sort_filenames(filenames):
    def extract_keys(name):
        # 提取 S、C、P、R、A 后面的数字
        s = int(name[1:4])
        c = int(name[5:8])
        p = int(name[9:12])
        r = int(name[13:16])
        a = int(name[17:20])
        return (s, c, p, r, a)

    # 按照提取的键进行排序
    return sorted(filenames, key=extract_keys)

# 使用示例
input_file = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/statistics/skes_available_name.txt'

filenames = read_filenames_from_file(input_file)
sorted_filenames = sort_filenames(filenames)
write_filenames_to_file(sorted_filenames, input_file)

print(f"Sorted filenames have been written to {input_file}")
# Out:
# Sorted filenames have been written to /content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/statistics/skes_available_name.txt

# %%
# remove samples_with_missing_skeletons files
base_path = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/statistics'
missing_skeletons_file = os.path.join(base_path, 'samples_with_missing_skeletons.txt')
available_skeletons_file = os.path.join(base_path, 'skes_available_name.txt')
with open(missing_skeletons_file, 'r') as f:
  missing_skeletons = set(line.strip() for line in f)
with open(available_skeletons_file, 'r') as f:
    available_skeletons = [line.strip() for line in f if line.strip() not in missing_skeletons]

with open(available_skeletons_file, 'w') as f:
    for skeleton in available_skeletons:
        f.write(skeleton + '\n')

print(f"Updated {available_skeletons_file} by removing missing skeleton names.")
# Out:
# Updated /content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/statistics/skes_available_name.txt by removing missing skeleton names.

# %%
def extract_numbers_from_filename(filename):
    # 提取 S、C、P、R、A 后面的数字
    s = int(filename[1:4])
    c = int(filename[5:8])
    p = int(filename[9:12])
    r = int(filename[13:16])
    a = int(filename[17:20])
    return s, c, p, r, a

def clear_files(*files):
  for file in files:
      open(file, 'w').close()

def write_numbers_to_files(filenames, setup_file, camera_file, performer_file, replication_file, label_file):
  # 清空文件内容
  clear_files(setup_file, camera_file, performer_file, replication_file, label_file)
  with open(setup_file, 'w') as sf, \
         open(camera_file, 'w') as cf, \
         open(performer_file, 'w') as pf, \
         open(replication_file, 'w') as rf, \
         open(label_file, 'w') as lf:

    for filename in filenames:
      # s, c, p, r, a = extract_numbers_from_filename(filename)
      result = extract_numbers_from_filename(filename)
      e=0
      if result:  # Check if extraction was successful
        s, c, p, r, a = result
      else:
        print(e)
      sf.write(f"{s}\n")
      cf.write(f"{c}\n")
      pf.write(f"{p}\n")
      rf.write(f"{r}\n")
      lf.write(f"{a}\n")

base_path = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/statistics'
input_file = os.path.join(base_path,'skes_available_name.txt')
setup_file = os.path.join(base_path,'setup.txt')
camera_file = os.path.join(base_path,'camera.txt')
performer_file = os.path.join(base_path,'performer.txt')
replication_file = os.path.join(base_path,'replication.txt')
label_file = os.path.join(base_path,'label.txt')

# 读取文件名
with open(input_file, 'r') as f:
    skes_names = f.read().splitlines()
print(skes_names[0],extract_numbers_from_filename(skes_names[0]))

# 写入各个文件
write_numbers_to_files(skes_names, setup_file, camera_file, performer_file, replication_file, label_file)

print("Numbers have been extracted and written to the respective files.")
# Out:
# S001C001P001R001A001 (1, 1, 1, 1, 1)
# Numbers have been extracted and written to the respective files.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

# 更改当前工作目录
os.chdir('/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu')

# 确认当前工作目录
print("Current Working Directory: ", os.getcwd())

# 运行Python脚本
# !python get_raw_skes_data.py
# Out:
# Current Working Directory:  /content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu
# Found 113945 available skeleton files.
# Reading data from S001C001P001R001A001.skeleton
# Reading data from S001C001P001R001A002.skeleton
# Reading data from S001C001P001R001A003.skeleton
# Reading data from S001C001P001R001A004.skeleton
# Reading data from S001C001P001R001A005.skeleton
# Reading data from S001C001P001R001A006.skeleton
# Reading data from S001C001P001R001A007.skeleton
# Reading data from S001C001P001R001A008.skeleton
# Reading data from S001C001P001R001A009.skeleton
# Reading data from S001C001P001R001A010.skeleton
# Reading data from S001C001P001R001A011.skeleton
# Reading data from S001C001P001R001A012.skeleton
# Reading data from S001C001P001R001A013.skeleton
# Reading data from S001C001P001R001A014.skeleton
# Reading data from S001C001P001R001A015.skeleton
# Reading data from S001C001P001R001A016.skeleton
# ...

# %%
import os

# 更改当前工作目录
os.chdir('/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu')

# Remove the bad skeleton
# !python get_raw_denoised_data.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Processing S031C003P043R001A087
# Processing S031C003P043R001A088
# Processing S031C003P043R001A089
# Processing S031C003P043R001A090
# Processing S031C003P043R001A091
# Processing S031C003P043R001A092
# Processing S031C003P043R001A093
# Processing S031C003P043R001A094
# Processing S031C003P043R001A095
# Processing S031C003P043R001A096
# Processing S031C003P043R001A097
# Processing S031C003P043R001A098
# Processing S031C003P043R001A099
# Processing S031C003P043R001A100
# Processing S031C003P043R001A101
# Processing S031C003P043R001A102
# Processing S031C003P043R001A103
# Processing S031C003P043R001A104
# Processing S031C003P043R001A105
# Processing S031C003P043R001A106
# Processing S031C003P043R001A107
# Processing S031C003P043R001A108
# Processing S031C003P043R001A109
# Processing S031C003P043R001A110
# Processing S031C003P043R001A111
# Processing S031C003P043R001A112
# Processing S031C003P043R001A113
# Processing S031C003P043R001A114
# ...

# %%
# How it look like
input_file_path = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/denoised_data/raw_denoised_joints.txt'
output_file_path = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/denoised_data/samples_raw_denoised_data.txt'
# # 打开文件并读取前几行
# with open(file_path, 'r', encoding='utf-8') as file:
#     # print(len(file.readlines()))
#     num_elements_to_read = 5  # 要读取的元素数量5
#     lines = []
#     for _ in range(num_elements_to_read):
#         line = file.readline().strip()  # 读取一行并去除首尾空白符

#         lines.append(line)
#         print(line)
#         # 将读取的行写入新的文件中
#         with open(output_file_path, 'w', encoding='utf-8') as output_file:
#             for line in lines:
#                 output_file.write(line + '\n')  # 写入每一行并换行

# print(f"前{num_elements_to_read}个元素已写入文件：{output_file_path}")

# 用于计算字符串中的数字个数的函数
def count_numbers_in_line(line):
    return len(re.findall(r'\d', line))

# 打开输入文件进行读取
with open(input_file_path, 'r', encoding='utf-8') as infile:
    # 打开输出文件进行写入
    with open(output_file_path, 'w', encoding='utf-8') as outfile:
        # 遍历输入文件的每一行
        for line in infile:
            # 检查行是否以 'SkesNo' 开头
            if line.startswith('SkesNo'):
                # 如果是，则写入到输出文件
                outfile.write(line)

# %%
import os
# check actor_info
actors_infor_path = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/denoised_data/actors_info'
S001C001P001R001A001 = os.path.join(actors_infor_path,'S001C001P001R001A001.txt')
with open('S001C001P001R001A001','r') as f:
  print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-03d0dfacb8bd> in <cell line: 5>()
#       3 actors_infor_path = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/data/ntu/denoised_data/actors_info'
#       4 S001C001P001R001A001 = os.path.join(actors_infor_path,'S001C001P001R001A001.txt')
# ----> 5 with open('S001C001P001R001A001','r') as f:
#       6   print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'S001C001P001R001A001'

# %%
# Transform the skeleton to the center of the first frame splip the dataset cross view(camaras)
# camara2,3: training set; camara1: testing set
# validation set: splitting 5% data randomly from training set
# !python seq_transformation.py

# %%
# For CNN-based model without view adaptation module
# !python  va-cnn.py --model baseline --aug 1 --train 1
