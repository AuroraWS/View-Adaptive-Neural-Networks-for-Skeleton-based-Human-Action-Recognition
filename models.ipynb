# %% [markdown]
# <a href="https://colab.research.google.com/github/AuroraWS/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition/blob/master/models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For CNN-based model without view adaptation module
base_path2 = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition'
import os

# 更改当前工作目录
os.chdir(base_path2)

# 确认当前工作目录
print("Current Working Directory: ", os.getcwd())

# 启用同步模式，这样可以更容易地定位错误：
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# 运行Python脚本
# !python  va-cnn.py --model VA --aug 1 --train 1
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# epoch 14, Batch 84
# epoch 14, Batch 85
# epoch 14, Batch 86
# epoch 14, Batch 87
# epoch 14, Batch 88
# epoch 14, Batch 89
# epoch 14, Batch 90
# epoch 14, Batch 91
# epoch 14, Batch 92
# epoch 14, Batch 93
# epoch 14, Batch 94
# epoch 14, Batch 95
# epoch 14, Batch 96
# epoch 14, Batch 97
# epoch 14, Batch 98
# epoch 14, Batch 99
# Epoch-15  100 batches	loss 0.0709 (0.0951)	accu 98.828 (97.605)
# epoch 14, Batch 100
# epoch 14, Batch 101
# epoch 14, Batch 102
# epoch 14, Batch 103
# epoch 14, Batch 104
# epoch 14, Batch 105
# epoch 14, Batch 106
# epoch 14, Batch 107
# epoch 14, Batch 108
# epoch 14, Batch 109
# epoch 14, Batch 110
# epoch 14, Batch 111
# epoch 14, Batch 112
# epoch 14, Batch 113
# epoch 14, Batch 114
# epoch 14, Batch 115
# epoch 14, Batch 116
# epoch 14, Batch 117
# epoch 14, Batch 118
# epoch 14, Batch 119
# Epoch-15  120 batches	loss 0.0821 (0.0930)	accu 98.047 (97.669)
# epoch 14, Batch 120
# epoch 14, Batch 121
# ...

# %%
# For CNN-based model without view adaptation module
base_path2 = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition'
import os

# 更改当前工作目录
os.chdir(base_path2)

# 确认当前工作目录
print("Current Working Directory: ", os.getcwd())

# 启用同步模式，这样可以更容易地定位错误：
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# 运行Python脚本
# !python  va-cnn.py --model baseline --aug 1 --train 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-77bfc326398e> in <cell line: 6>()
#       4
#       5 # 更改当前工作目录
# ----> 6 os.chdir(base_path2)
#       7
#       8 # 确认当前工作目录
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition'

# %%
# For CNN-based model without view adaptation module
base_path2 = '/content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition'
import os

# 更改当前工作目录
os.chdir(base_path2)

# 确认当前工作目录
print("Current Working Directory: ", os.getcwd())

# 启用同步模式，这样可以更容易地定位错误：
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# 运行Python脚本
# !python  va-cnn.py --model VA --aug 1 --train 0
#
# Out:
# Current Working Directory:  /content/drive/Othercomputers/我的笔记本电脑/View-Adaptive-Neural-Networks-for-Skeleton-based-Human-Action-Recognition
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 171MB/s]
# ...
